# %% [markdown]
# Exploratory data analysis of the Pulotu database. This database has been used to test cultural evolutionary hypotheses regarding the relationships between supernatural beliefs, conflict, and large-scale cooperation.
#
# 5 csv files are included with the database. I explore all of them, but the fourth dataframe (questions) was the only one that I could explore in a worthwile manner.
#
# I am interested in how evolutionary anthropologists code their data, i.e., how they label complex cultural concepts, such as gods and other supernatural beliefs. Further down my (failed) attempt to visualise these relationships is shown.

# %%
import pandas as pd
df = pd.read_csv('cultures.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            137 non-null    object
#  1   Name          137 non-null    object
#  2   Macroarea     0 non-null      float64
#  3   Latitude      137 non-null    float64
#  4   Longitude     137 non-null    float64
#  5   Glottocode    129 non-null    object
#  6   ISO639P3code  0 non-null      float64
#  7   Comment       107 non-null    object
#  8   Ethonyms      94 non-null     object
# dtypes: float64(4), object(5)
# memory usage: 9.8+ KB
#          ID      Name  Macroarea  Latitude  Longitude Glottocode  \
# 0    puyuma    Puyuma        NaN      22.8      121.1   puyu1239
# 1   subanun   Subanun        NaN       7.1      122.1        NaN
# 2     tanna     Tanna        NaN     -19.5      169.4   kwam1252
# 3      tsou      Tsou        NaN      23.4      120.7   tsou1248
# ...

# %%
df.tail()
# Out:
#                      ID                Name  Macroarea  Latitude  Longitude  \
# 132   casiguran-dumagat   Casiguran Dumagat        NaN      16.3      122.0
# 133           erromango           Erromango        NaN     -18.8      169.2
# 134           hawaiians           Hawaiians        NaN      19.6     -155.5
# 135                kodi                Kodi        NaN      -9.6      119.0
# 136  manihiki-rakahanga  Manihiki-Rakahanga        NaN     -10.4     -161.0
#
#     Glottocode  ISO639P3code  \
# 132   casi1235           NaN
# 133   urav1235           NaN
# 134   hawa1245           NaN
# 135   kodi1247           NaN
# 136   raka1237           NaN
#
#                                                Comment             Ethonyms
# 132  The Casiguran Dumagat are one of the many 'Neg...        Agta; Dumagat
# 133  Erromango is a small, high island in the south...  Eromanga; Erromanga
# 134  The Hawaiian Islands represent one of the most...                Maoli
# ...

# %%
df.describe()
# Out:
#        Macroarea    Latitude   Longitude  ISO639P3code
# count        0.0  137.000000  137.000000           0.0
# mean         NaN   -4.002920  101.689051           NaN
# std          NaN   13.119473  101.591430           NaN
# min          NaN  -43.800000 -178.000000           NaN
# 25%          NaN  -10.700000  119.000000           NaN
# 50%          NaN   -8.200000  125.200000           NaN
# 75%          NaN    3.800000  159.800000           NaN
# max          NaN   24.400000  178.000000           NaN

# %%
df2 = pd.read_csv('codes.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            258 non-null    object
#  1   Parameter_ID  258 non-null    int64
#  2   Name          258 non-null    object
#  3   Description   257 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 8.2+ KB

# %%
df2.describe()
# Out:
#        Parameter_ID
# count    258.000000
# mean      44.581395
# std       23.422427
# min        2.000000
# 25%       23.250000
# 50%       49.000000
# 75%       63.000000
# max       83.000000

# %%
df3 = pd.read_csv('glossary.csv')
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          65 non-null     object
#  1   Term        65 non-null     object
#  2   Definition  65 non-null     object
#  3   Source      3 non-null      object
# dtypes: object(4)
# memory usage: 2.2+ KB

# %%
df3.describe()
# Out:
#                         ID              Term  \
# count                   65                65
# unique                  65                65
# top     volcanichighisland  Top-down process
# freq                     1                 1
#
#                                                Definition       Source
# count                                                  65            3
# unique                                                 65            3
# top     Behaviour that directly offends a supernatural...  swanson1960
# freq                                                    1            1

# %%
df4 = pd.read_csv('questions.csv')
df4.head()
# Out:
#    ID                           Name  \
# 0   1   Traditional State Time Focus
# 1   2               Belief in god(s)
# 2   3        Belief in nature god(s)
# 3   4  Belief in deified ancestor(s)
# 4   5    Belief in ancestral spirits
#
#                                          Description         Simplified_Name  \
# 0  A time focus is the period of time to which et...  Traditional Time Focus
# 1  A god is a supernatural agent with a broad sph...                  God(s)
# 2  A nature god is a supernatural agent of non-hu...           Nature god(s)
# 3  A deified ancestor is the spirit of a human or...     Deified ancestor(s)
# 4  An ancestral spirit is the spirit of a decease...       Ancestral spirits
#
#   Datatype Section_Notes             Category                       Section  \
# 0     Text           NaN  Traditional Culture  Traditional State Time Focus
# 1   Option           NaN  Traditional Culture           Belief (Indigenous)
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               83 non-null     int64
#  1   Name             83 non-null     object
#  2   Description      66 non-null     object
#  3   Simplified_Name  34 non-null     object
#  4   Datatype         83 non-null     object
#  5   Section_Notes    27 non-null     object
#  6   Category         83 non-null     object
#  7   Section          83 non-null     object
#  8   Subsection       83 non-null     object
# dtypes: int64(1), object(8)
# memory usage: 6.0+ KB

# %%
df4['Category'].value_counts()
# Out:
# Traditional Culture     63
# Post Contact History    16
# Current Culture          4
# Name: Category, dtype: int64

# %%
df4.shape
# Out:
# (83, 9)

# %%
df4['Section'].value_counts()
# Out:
# Belief (Indigenous)             20
# Secular History                 11
# Subsistence and Economy         10
# Social Environment              10
# Practice (Indigenous)            9
# Isolation                        7
# Physical Environment             6
# Religious History                5
# Belief (Current)                 3
# Traditional State Time Focus     1
# Current Time Focus               1
# Name: Section, dtype: int64

# %%
df4['Subsection'].value_counts()
# Out:
# Isolation                                             7
# Social Environment                                    7
# Supernatural Beings                                   5
# Land-based means of subsistence                       5
# Mana                                                  5
# Rites                                                 5
# Afterlife and Creation                                5
# General Supernatural Practices (Indigenous)           4
# Demographic and Social Changes                        4
# Conversion                                            4
# Conflict                                              3
# Classes of Tapu                                       3
# Water-based means of subsistence                      3
# Modern Infrastructure                                 3
# Religious Demographics                                3
# Features of Island with Largest Culture Population    3
# Loss of Autonomy                                      2
# ...

# %%
pd.crosstab(df4['Section'], df4['Category'])
# Out:
# Category                      Current Culture  Post Contact History  \
# Section
# Belief (Current)                            3                     0
# Belief (Indigenous)                         0                     0
# Current Time Focus                          1                     0
# Isolation                                   0                     0
# Physical Environment                        0                     0
# Practice (Indigenous)                       0                     0
# Religious History                           0                     5
# Secular History                             0                    11
# Social Environment                          0                     0
# Subsistence and Economy                     0                     0
# Traditional State Time Focus                0                     0
#
# Category                      Traditional Culture
# Section
# Belief (Current)                                0
# ...

# %%
pd.crosstab(df4['Section'], df4['Category']).plot.barh()
#Unfortunately, this visualisation is not very interesting because every section is mapped to only one category. 
#In other words, every section on the y axis always only belongs to one category. I hoped to have seen 3 bars on every section.
# Out:
# <AxesSubplot:ylabel='Section'>

# %%
df4[['Simplified_Name', 'Category', 'Section']]
#I wanted to visualise these 3 categorical variables together, but I could not find out how.
# Out:
#                        Simplified_Name              Category  \
# 0               Traditional Time Focus   Traditional Culture
# 1                               God(s)   Traditional Culture
# 2                        Nature god(s)   Traditional Culture
# 3                  Deified ancestor(s)   Traditional Culture
# 4                    Ancestral spirits   Traditional Culture
# ..                                 ...                   ...
# 78          Nature of loss of autonomy  Post Contact History
# 79             Contemporary Time Focus       Current Culture
# 80     Unofficial religious syncretism       Current Culture
# 81  Institutional religious syncretism       Current Culture
# 82                                 NaN       Current Culture
#
#                          Section
# 0   Traditional State Time Focus
# 1            Belief (Indigenous)
# 2            Belief (Indigenous)
# 3            Belief (Indigenous)
# 4            Belief (Indigenous)
# ...

# %%
import seaborn as sns
section_counts = df4['Section'].value_counts()
sns.boxplot(x='section_counts', col = 'Simplified_Name', data = df4)
#Unfortunately, this returns an error. My idea was to visualise the counts of the section column and create a boxplot paired to the categorical variable 'simplified_name' to figure out the researchers labeled their data.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-6f3ed6f7b515> in <module>
#       1 import seaborn as sns
#       2 section_counts = df4['Section'].value_counts()
# ----> 3 sns.boxplot(x='section_counts', col = 'Simplified_Name', data = df4)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# -> 2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
# ...

# %%
df5 = pd.read_csv('responses.csv')
df5.head()
# Out:
#      ID Language_ID  Parameter_ID Value Code_ID  Comment  \
# 0     5       manam            30  -4.1     NaN      NaN
# 1     6       manam            29   145     NaN      NaN
# 2     7       manam            32     2     7-2      NaN
# 3     8       manam            34    90     NaN      NaN
# 4  8105         yap            68     0    87-0      NaN
#
#                       Source
# 0            google-mapsnone
# 1            google-mapsnone
# 2          lutkehaus1995[39]
# 3          lutkehaus1995[40]
# 4  lingenfelter1972[269-272]

# %%
df5.shape
# Out:
# (9793, 7)

# %%
df5.describe()
# Out:
#                  ID  Parameter_ID  Comment
# count   9793.000000   9793.000000      0.0
# mean    8145.869499     40.771265      NaN
# std     5862.184008     23.484771      NaN
# min        2.000000      1.000000      NaN
# 25%     3357.000000     22.000000      NaN
# 50%     7132.000000     40.000000      NaN
# 75%    10878.000000     61.000000      NaN
# max    21403.000000     83.000000      NaN

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9793 entries, 0 to 9792
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            9793 non-null   int64
#  1   Language_ID   9793 non-null   object
#  2   Parameter_ID  9793 non-null   int64
#  3   Value         9793 non-null   object
#  4   Code_ID       8596 non-null   object
#  5   Comment       0 non-null      float64
#  6   Source        9296 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 535.7+ KB
